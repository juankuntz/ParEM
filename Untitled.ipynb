# %%
import numpy as np

#!git clone https://github.com/juankuntz/ParEM.git
    
import sys
sys.path.insert(1, './ParEM')
import theta

X = np.zeros((10, 20))  # Initial particle cloud.

print(theta.theta(X))
# Out:
# 0.0
